# %%
# !pip install -q -U google-genai

# %%
'''SERP API INTEGRATION'''
import requests
import json # Necessary for json.dumps()
from google.genai.types import FunctionDeclaration, Type, Schema
from google.colab import userdata

# NOTE: Replace 'YOUR_SERPAPI_KEY' with your actual key from the service
SERPAPI_API_KEY = 'YOUR_SERPAPI_KEY'

def serp_job_search_tool(query: str) -> str:
    """
    Uses an external SERP API to fetch structured job data, including application links.
    Returns the result as a JSON string for the LLM to process.
    """
    if not globals().get('SERPAPI_API_KEY') or globals()['SERPAPI_API_KEY'] == 'PLACEHOLDER':
        return json.dumps({"error": "SERPAPI_API_KEY is not configured. Live search failed."})

    # Actual SERP API Call (Example using SerpApi)
    params = {
      "api_key": SERPAPI_API_KEY,
      "engine": "google_jobs",
      "q": query,
      "hl": "en",
      "gl": "in",
    }

    try:
        # Make the actual API request
        response = requests.get("https://serpapi.com/search", params=params)
        response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)

        data = response.json()

        # We only care about the structured job results section
        jobs_results = data.get('jobs_results', [])

        if not jobs_results:
            return json.dumps({"error": "No jobs found for the query.", "raw_response": data})

        # Return the clean, structured list of job results as a JSON string
        return json.dumps({"jobs_results": jobs_results})

    except requests.exceptions.RequestException as e:
        return json.dumps({"error": f"API Request failed: {e}"})
    except Exception as e:
        return json.dumps({"error": f"An unexpected error occurred: {e}"})


# 2. Function Declaration for the SERP tool
SERP_TOOL_DECLARATION = FunctionDeclaration(
    name='serp_job_search_tool',
    description='Fetches structured job postings and direct application links for a given query using a powerful external API.',
    parameters=Schema(
        type=Type.OBJECT,
        properties={
            'query': Schema(type=Type.STRING, description='The job title and location to search for.'),
        },
        required=['query']
    )
)

# %%
import os
import json
import requests
from google.colab import userdata

# --- CRITICAL IMPORTS FOR GEMINI SDK TYPES ---
from google import genai
from google.genai.types import (
    FunctionDeclaration,
    Type,
    Schema,
    Tool,
    GenerateContentConfig,
    Part,
    Content
)
from google.genai import types

# --- SETUP: Configuration and API Key Loading ---
print("--- 1. Setting up the environment ---")

try:
    print("Installing/Updating necessary libraries...")
    # !pip install -q -U google-genai requests
except Exception as e:
    print(f"Error during package installation: {e}")

# Initialize placeholders
API_KEY = None
SERPAPI_API_KEY = None
client = None

# Load API Keys from Colab Secrets
try:
    API_KEY = userdata.get('GOOGLE_API_KEY')
    if not API_KEY:
        raise ValueError("GOOGLE_API_KEY not found in Colab Secrets.")

    # FIXED: Use the correct secret name
    SERPAPI_API_KEY = userdata.get('SERPAPI_API_KEY')  # Changed from YOUR_SERPAPI_KEY
    if not SERPAPI_API_KEY:
        raise ValueError("SERPAPI_API_KEY not found in Colab Secrets.")

    client = genai.Client(api_key=API_KEY)
    AGENT_MODEL = 'gemini-2.5-flash'
    print("✅ Gemini API client and SERPAPI_API_KEY configured successfully.")
    print(f"   SERPAPI_API_KEY loaded: {SERPAPI_API_KEY[:10]}..." if SERPAPI_API_KEY else "   No key loaded")

except Exception as e:
    print(f"❌ ERROR: Configuration failed. Details: {e}")
    AGENT_MODEL = 'gemini-2.5-flash'


# --- CUSTOM TOOL DEFINITIONS ---

def serp_job_search_tool(query: str) -> str:
    """
    Uses the live SerpApi to fetch structured Google Jobs data.
    Enhanced with better error handling and debugging.
    """
    print(f"\n🔍 SERP Tool Called with query: '{query}'")

    if not SERPAPI_API_KEY or SERPAPI_API_KEY == 'PLACEHOLDER':
        error_msg = "SERPAPI_API_KEY is missing or invalid."
        print(f"❌ {error_msg}")
        return json.dumps({"error": error_msg, "jobs_results": []})

    # IMPROVED: More flexible search parameters
    params = {
        "api_key": SERPAPI_API_KEY,
        "engine": "google_jobs",
        "q": query,
        "hl": "en",
        "gl": "in",
        # REMOVED: "chips": "date_posted:month" - This might be too restrictive
    }

    try:
        print(f"   Making API request to SerpAPI...")
        response = requests.get("https://serpapi.com/search", params=params, timeout=10)

        # Debug: Print status code
        print(f"   Response status: {response.status_code}")

        response.raise_for_status()
        data = response.json()

        # Debug: Print API response structure
        print(f"   API Response keys: {list(data.keys())}")

        # Check for API errors
        if "error" in data:
            error_msg = f"SerpAPI Error: {data['error']}"
            print(f"❌ {error_msg}")
            return json.dumps({"error": error_msg, "jobs_results": []})

        jobs_results = data.get('jobs_results', [])

        print(f"   Jobs found: {len(jobs_results)}")

        if not jobs_results:
            # IMPROVED: Return more diagnostic information
            return json.dumps({
                "jobs_results": [],
                "error": "No jobs found for the query.",
                "debug_info": {
                    "query_used": query,
                    "search_metadata": data.get("search_metadata", {}),
                    "suggestion": "Try a broader search term like 'Software Developer India' or 'Java Developer'"
                }
            })

        # Success: Return structured results
        print(f"✅ Successfully retrieved {len(jobs_results)} jobs")
        return json.dumps({"jobs_results": jobs_results[:5]})  # Limit to top 5

    except requests.exceptions.Timeout:
        error_msg = "API request timed out. Please try again."
        print(f"❌ {error_msg}")
        return json.dumps({"error": error_msg, "jobs_results": []})

    except requests.exceptions.RequestException as e:
        error_msg = f"API Request failed: {str(e)}"
        print(f"❌ {error_msg}")
        return json.dumps({"error": error_msg, "jobs_results": []})

    except Exception as e:
        error_msg = f"Unexpected error: {str(e)}"
        print(f"❌ {error_msg}")
        return json.dumps({"error": error_msg, "jobs_results": []})


# Function Declaration for the SERP tool
SERP_TOOL_DECLARATION = FunctionDeclaration(
    name='serp_job_search_tool',
    description='Fetches structured job postings including title, company, link, and description for a given query.',
    parameters=Schema(
        type=Type.OBJECT,
        properties={'query': Schema(type=Type.STRING, description='The job title and location to search for.')},
        required=['query']
    )
)


def log_job_to_db(job_title: str, company: str, status: str) -> str:
    """Logs a job posting to simulated database."""
    log_entry = {"title": job_title, "company": company, "status": status}
    print(f"📝 [JobDatabaseTool]: Logging job: {json.dumps(log_entry)}")
    return f"Job '{job_title}' successfully logged with status '{status}'."


LOG_TOOL_DECLARATION = FunctionDeclaration(
    name='log_job_to_db',
    description='Logs a job posting and its status to a simulated persistent database.',
    parameters=Schema(
        type=Type.OBJECT,
        properties={
            'job_title': Schema(type=Type.STRING, description='The exact title of the job posting.'),
            'company': Schema(type=Type.STRING, description='The name of the company offering the job.'),
            'status': Schema(type=Type.STRING, description='The current review status.')
        },
        required=['job_title', 'company', 'status']
    )
)


# --- AGENT DEFINITIONS ---

def search_agent(query: str, client: genai.Client, model: str) -> str:
    """Search Agent - Uses SERP tool to find structured job postings."""
    if client is None:
        return "No job data found. Gemini client not initialized."

    print(f"\n⚙️ Search Agent received query: '{query}'")

    system_instruction = (
        "You are the expert Search Agent. You **must** use the `serp_job_search_tool` "
        "to find relevant job postings. When you receive the structured JSON data, your **PRIMARY** goal is to extract " "the Title, Company, Location, Description, and the **FULL APPLICATION URL**. "
        "Format the data into a clean, numbered list, ensuring the **Application Link** is clearly labeled and included for every job. "
        "This link must be preserved exactly as it appears in the JSON (usually under 'apply_link' or 'related_links')."
    )

    tools = [Tool(function_declarations=[SERP_TOOL_DECLARATION])]

    prompt = f"Find job postings for: {query}"

    # First call: Request function call
    response = client.models.generate_content(
        model=model,
        contents=prompt,
        config=GenerateContentConfig(
            system_instruction=system_instruction,
            tools=tools,
            tool_config=types.ToolConfig(
                function_calling_config=types.FunctionCallingConfig(mode='ANY')
            )
        )
    )

    # Tool Execution
    if response.function_calls:
        print("    [Function Call Detected]: Executing serp_job_search_tool...")

        call = response.function_calls[0]
        job_data_json = serp_job_search_tool(**dict(call.args))

        # Parse to check for errors
        job_data = json.loads(job_data_json)

        # IMPROVED: Better error handling
        if job_data.get("error"):
            error_message = job_data["error"]
            debug_info = job_data.get("debug_info", {})
            suggestion = debug_info.get("suggestion", "Try different search terms")

            return f"⚠️ Search failed: {error_message}\n\n💡 Suggestion: {suggestion}"

        # Second call: Get formatted response
        response = client.models.generate_content(
            model=model,
            contents=[
                Content(role='user', parts=[Part(text=prompt)]),
                Content(role='model', parts=[Part(function_call=call)]),
                Content(role='function', parts=[Part(function_response=types.FunctionResponse(
                    name='serp_job_search_tool',
                    response={'job_data': job_data_json}
                ))])
            ],
            config=GenerateContentConfig(system_instruction=system_instruction)
        )

        print("✅ Search Agent finished.")
        return response.text
    else:
        print("⚠️ Warning: Search Agent did not call the SERP tool.")
        return "No job data found. Model failed to execute tool call."


def analysis_agent(job_list_text: str, user_profile: str, client: genai.Client, model: str) -> str:
    """Analysis Agent - Reviews and scores job matches."""
    print("\n⚙️ Analysis Agent started review...")

    system_instruction = (
        "You are the Analysis Agent. Review the job postings against the user profile, "
        "log each job using `log_job_to_db`, then provide detailed analysis with match scores (1-10)."
    )

    tools = [LOG_TOOL_DECLARATION]

    prompt = (
        f"Analyze these jobs against this profile: {user_profile}\n\n"
        f"For each job: 1) Log it with log_job_to_db, 2) Provide analysis and score.\n\n"
        f"Jobs:\n{job_list_text}"
    )

    response = client.models.generate_content(
        model=model,
        contents=prompt,
        config=GenerateContentConfig(system_instruction=system_instruction, tools=tools)
    )

    # Handle logging tool calls
    function_responses = []
    for part in response.candidates[0].content.parts:
        if part.function_call and part.function_call.name == 'log_job_to_db':
            call = part.function_call
            log_result = log_job_to_db(**dict(call.args))
            function_responses.append(Part(function_response=types.FunctionResponse(
                name='log_job_to_db',
                response={'result': log_result}
            )))

    if function_responses:
        response = client.models.generate_content(
            model=model,
            contents=[
                Content(role='user', parts=[Part(text=prompt)]),
                response.candidates[0].content,
                Content(role='function', parts=function_responses)
            ],
            config=GenerateContentConfig(system_instruction=system_instruction)
        )

    print("✅ Analysis Agent finished.")
    return response.text


def recruiter_agent(prompt: str, user_profile: str, client: genai.Client, model: str) -> str:
    """Recruiter Agent - Orchestrates the job search process."""
    print("\n" + "="*50)
    print("🎯 RECRUITER AGENT STARTING")
    print("="*50)

    search_query = prompt
    job_list_text = search_agent(search_query, client, model)

    # Check for search failure
    if "Search failed" in job_list_text or "No job data found" in job_list_text:
        return f"**Job Search Failed**\n\n{job_list_text}"

    final_analysis_text = analysis_agent(job_list_text, user_profile, client, model)

    # Synthesis
    system_instruction = (
        "You are the Recruiter Agent. Synthesize the analysis into a clear job recommendation report. "
        "Present the top matches with scores and application links."
    )

    synthesis_prompt = (
        f"Create a final job recommendation report from this analysis. "
        f"Highlight the top 2 best matches and **ensure the full application URL is clearly displayed** "
        f"for each highlighted job, using a bold 'Application Link:' label. User request: '{prompt}'\n\nAnalysis:\n{final_analysis_text}"
    )

    final_response = client.models.generate_content(
        model=model,
        contents=synthesis_prompt,
        config=GenerateContentConfig(system_instruction=system_instruction)
    )

    print("="*50)
    print("✅ RECRUITER AGENT FINISHED")
    print("="*50)
    return final_response.text


# --- MAIN EXECUTION ---

USER_PROFILE = """
I am a Software Engineer
Skills: Java, Javascript, React, Spring-boot, Agile.
"""

USER_JOB_REQUEST = "Software Engineer jobs in India"

print("\n\n" + "#"*50)
print("🔥 AI AGENTS RECRUITER SYSTEM")
print("#"*50 + "\n")

if client:
    final_report = recruiter_agent(
        prompt=USER_JOB_REQUEST,
        user_profile=USER_PROFILE,
        client=client,
        model=AGENT_MODEL
    )
    print("\n\n" + "="*50)
    print("📊 FINAL REPORT")
    print("="*50)
    print(final_report)
else:
    print("❌ Cannot run: Gemini client not initialized. Check your API keys.")
# Out:
# --- 1. Setting up the environment ---
# Installing/Updating necessary libraries...
# ✅ Gemini API client and SERPAPI_API_KEY configured successfully.
#    SERPAPI_API_KEY loaded: ad218a15e4...
#
#
# ##################################################
# 🔥 AI AGENTS RECRUITER SYSTEM
# ##################################################
#
#
# ==================================================
# 🎯 RECRUITER AGENT STARTING
# ==================================================
#
# ⚙️ Search Agent received query: 'Software Engineer jobs in India'
#     [Function Call Detected]: Executing serp_job_search_tool...
#
# 🔍 SERP Tool Called with query: 'Software Engineer jobs in India'
#    Making API request to SerpAPI...
#    Response status: 200
#    API Response keys: ['search_metadata', 'search_parameters', 'filters', 'jobs_results', 'serpapi_pagination']
#    Jobs found: 10
# ✅ Successfully retrieved 10 jobs
# ✅ Search Agent finished.
#
# ⚙️ Analysis Agent started review...
# ✅ Analysis Agent finished.
# ==================================================
# ✅ RECRUITER AGENT FINISHED
# ==================================================
#
#
# ==================================================
# 📊 FINAL REPORT
# ==================================================
# Here is your personalized Job Recommendation Report based on the analysis of available "Software Engineer" roles in India, tailored to your profile.
#
# ---
#
# ### **Job Recommendation Report: Software Engineer - India**
#
# **User Profile:**
# *   **Role:** Software Engineer
# *   **Skills:** Java, Javascript, React, Spring-boot, Agile
#
# ---
#
# ### **Overall Summary of Matches:**
#
# | Job Title                                           | Company               | Location                               | Match Score | Key Notes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | :-------------------------------------------------- | :-------------------- | :------------------------------------- | :---------- | :---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Manager, Engineering - Java, Springboot             | Ivanti                | Sahibzada Ajit Singh Nagar, Punjab     | **9/10**    | **Outstanding technical skill match for Java and Spring Boot.** This role is managerial, implying leadership responsibilities, which is a key consideration if you're looking for an individual contributor role. However, if you're open to career progression, it's an excellent opportunity due to the direct skill alignment.                                                                                                                                                                                                                                                             |
# | Software Engineer                                   | NatWest Digital X     | Gurugram, Haryana                      | **7/10**    | Strong direct role match for "Software Engineer." While specific technical skills (Java, Spring Boot, React) are not explicitly listed, the context of a financial institution and "feature team" suggests a high probability of relevance for your core backend and Agile skills. A solid general Software Engineer opportunity.                                                                                                                                                                                                                                                                |
# | Sr. SW Engineer                                     | Roku                  | Bengaluru, Karnataka                   | 5/10        | Good role match as a Senior Software Engineer. However, the job description is entirely devoid of technical skill requirements, making it impossible to ascertain a true technical fit for your Java, Spring Boot, React stack. A potential fit, but highly uncertain without more information.                                                                                                                                                                                                                                                                                                      |
# | Software Engineer \| Chennai, India                 | Hitachi Energy        | Chennai, Tamil Nadu                    | 4/10        | Direct role match for "Software Engineer," but the description is extremely vague, providing no information on required technical skills or the nature of the work. It's impossible to determine skill relevance or overall fit from the provided details.                                                                                                                                                                                                                                                                                                                                             |
# | Senior Software Engineer - Mobile + Windows developer | ENABLERO              | Hyderabad, Telangana                   | 2/10        | While a "Senior Software Engineer" role, it's highly specialized in iOS (Swift/SwiftUI) and Windows desktop (C#.NET, WPF/XAML) development. These skills do not align with your Java, Javascript, React, Spring Boot expertise, making it a poor technical match despite the mention of "Agile." Requires a very specific skill set you do not possess based on your profile. |
#
# ---
#
# ### **Top 2 Recommended Job Matches:**
#
# Based on the analysis, these are the two most promising opportunities aligning with your profile:
#
# ---
#
# ### **1. Manager, Engineering - Java, Springboot at Ivanti**
#
# *   **Company:** Ivanti
# *   **Location:** Sahibzada Ajit Singh Nagar, Punjab
# *   **Match Score:** 9/10
# *   **Why it's a Top Match:** This role presents an exceptional technical fit for your core Java and Spring Boot expertise, which are explicitly mentioned in the job title and description. The focus on "next-generation cloud solutions" and "architecting and delivering robust, scalable, cloud-native applications" perfectly aligns with modern Spring Boot development practices. The mention of "guiding cross-functional teams and driving continuous improvement" also aligns well with your Agile experience. While the title is "Manager, Engineering" rather than a pure "Software Engineer" individual contributor role, it signifies a leadership position heavily rooted in your strongest technical skills, making it an excellent progression opportunity if you are looking to take on more responsibility and leadership while remaining hands-on with architecture and technical direction.
#
# *   **Application Link:** **https://en-in.whatjobs.com/jobs/software-engineer?id=204857423&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic**
#
# ---
#
# ### **2. Software Engineer at NatWest Digital X**
#
# *   **Company:** NatWest Digital X
# *   **Location:** Gurugram, Haryana
# *   **Match Score:** 7/10
# *   **Why it's a Top Match:** This is a strong direct match for a "Software Engineer" role. While the job description is more general and doesn't explicitly list specific programming languages, companies like NatWest (a major financial institution) frequently utilize Java and Spring Boot for their robust backend systems and often employ Javascript/React for their modern frontend applications. The emphasis on working within a "feature team" also strongly implies an Agile development environment, which matches your listed skills. This role offers a solid opportunity to apply your existing technical skills in a reputable organization, even with the generalized description.
#
# *   **Application Link:** **https://jobs.natwestgroup.com/jobs/17082450-software-engineer?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic**
#
# ---
#
# We recommend reviewing these top two opportunities in detail, paying close attention to the full job descriptions on their respective application pages. Good luck with your applications!

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Load email + app password from Colab/Kaggle secrets
SENDER_EMAIL = userdata.get("MY_EMAIL")
APP_PASSWORD = userdata.get("MY_EMAIL_APP_PASSWORD")

if not SENDER_EMAIL or not APP_PASSWORD:
    print("❌ Email credentials missing in secrets!")
else:
    print("✅ Email system ready.")
# Out:
# ✅ Email system ready.

# %%
def send_email(to_email: str, subject: str, body: str):
    """
    Sends an email using Gmail SMTP and App Password.
    """
    try:
        print("\n📨 Sending email...")

        msg = MIMEMultipart()
        msg["From"] = SENDER_EMAIL
        msg["To"] = to_email
        msg["Subject"] = subject

        msg.attach(MIMEText(body, "plain"))

        # Gmail SMTP
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(SENDER_EMAIL, APP_PASSWORD)

        server.sendmail(SENDER_EMAIL, to_email, msg.as_string())
        server.quit()

        print("✅ Email sent successfully!")

    except Exception as e:
        print(f"❌ Email sending failed: {e}")

# %%
if client:
    final_report = recruiter_agent(
        prompt=USER_JOB_REQUEST,
        user_profile=USER_PROFILE,
        client=client,
        model=AGENT_MODEL
    )
    print("\n\n" + "="*50)
    print("📊 FINAL REPORT")
    print("="*50)
    print(final_report)

    # === AUTOMATIC EMAIL DELIVERY ===
    RECIPIENT_EMAIL = userdata.get("MY_EMAIL")  # send to yourself

    print("\n📨 Auto-sending report to your email...")
    send_email(
        to_email=RECIPIENT_EMAIL,
        subject="Your Daily AI Job Report",
        body=final_report
    )
else:
    print("❌ Cannot run: Gemini client not initialized. Check your API keys.")
# Out:
# ==================================================
# 🎯 RECRUITER AGENT STARTING
# ==================================================
#
# ⚙️ Search Agent received query: 'Software Engineer jobs in India'
#     [Function Call Detected]: Executing serp_job_search_tool...
#
# 🔍 SERP Tool Called with query: 'Software Engineer jobs in India'
#    Making API request to SerpAPI...
#    Response status: 200
#    API Response keys: ['search_metadata', 'search_parameters', 'filters', 'jobs_results', 'serpapi_pagination']
#    Jobs found: 10
# ✅ Successfully retrieved 10 jobs
# ✅ Search Agent finished.
#
# ⚙️ Analysis Agent started review...
# ✅ Analysis Agent finished.
# ==================================================
# ✅ RECRUITER AGENT FINISHED
# ==================================================
#
#
# ==================================================
# 📊 FINAL REPORT
# ==================================================
# ## Job Recommendation Report for Software Engineer (India)
#
# Based on your profile as a **Software Engineer** with skills in **Java, Javascript, React, Spring-boot, and Agile**, the following analysis provides tailored job recommendations. Your core strengths lie in backend development with Java/Spring-boot and frontend development with React, along with a strong understanding of Agile methodologies.
#
# ### Overall Recommendation Summary
#
# After analyzing the available job postings, two roles stand out as excellent fits, directly leveraging your primary skills and aligning with your career as a Software Engineer. Another role, while technically strong in Java/Spring-boot, is fundamentally a management position, which is a significant departure from an individual contributor Software Engineer role.
#
# ---
#
# ### Top Recommended Jobs
#
# Here are the top 2 job recommendations, scoring highest for direct skill alignment, role relevance, and potential for growth within an individual contributor Software Engineer capacity:
#
# ---
#
# ### 1. Sr. SW Engineer - Roku
#
# **Score: 8.5/10**
#
# This role is an **excellent match** for your profile, especially if your "Software Engineer" experience leans heavily towards backend development. Roku is seeking a Senior Software Engineer with deep expertise in Java and Spring Boot to work on scalable backend systems and distributed data processing.
#
# *   **Role Match:** "Sr. SW Engineer" is a direct and relevant match for an experienced Software Engineer.
# *   **Skill Alignment:**
#     *   **Java:** Explicitly and extensively mentioned as a core requirement ("deep expertise in Java," "Proficiency in Java and Java-based frameworks").
#     *   **Spring-boot:** Explicitly mentioned as a key framework ("Leverage Java frameworks such as Spring Boot for backend development," "Spring, Spring Boot, etc.").
#     *   **Agile:** While not explicitly called out, it's an implied methodology in fast-paced, modern development environments like Roku's.
#     *   **Javascript/React:** Not mentioned as primary requirements, but the core backend focus perfectly aligns with your Java/Spring-boot strengths.
# *   **Location:** Bengaluru, Karnataka
#
# **Application Link:** **https://www.weareroku.com/jobs/sr-sw-engineer-bengaluru-karnataka-india-7453b88f-b1bc-4f26-9918-7444e79db3ea?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic**
#
# ---
#
# ### 2. Software Engineer - NatWest Digital X
#
# **Score: 7/10**
#
# This is a **strong match**, particularly emphasizing your frontend skills with React and your experience with Agile methodologies. It offers a clear path for a Software Engineer looking to contribute to innovative, customer-centric solutions.
#
# *   **Role Match:** "Software Engineer" is a direct match with your profile. The level is "senior analyst level," indicating a role for an experienced engineer.
# *   **Skill Alignment:**
#     *   **React:** Explicitly listed as a required skill ("Experience in React Js").
#     *   **Agile:** Explicitly listed as a required skill ("Agile methodology and associated toolsets").
#     *   **Java/Javascript:** While Java isn't explicitly listed, "multiple programming languages" is mentioned, and JavaScript is implied by the React requirement.
#     *   **Spring-boot:** Not explicitly mentioned.
# *   **Location:** Gurugram, Haryana
#
# **Application Link:** **https://jobs.natwestgroup.com/jobs/17082450-software-engineer?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic**
#
# ---
#
# ### Other Analyzed Jobs
#
# *   **Manager, Engineering - Java, Springboot - Ivanti**
#     *   **Score: 4/10**
#     *   **Analysis:** Technically, this role presents an excellent match for your Java, Spring-boot, and Agile skills, with React mentioned as a plus. However, it's explicitly an "Engineering Manager" position requiring 12-14 years of experience, with 3-4 years in management. This is a fundamental mismatch with your "Software Engineer" profile, which typically refers to an individual contributor role.
#
# *   **Senior Software Engineer - Mobile + Windows developer - ENABLERO**
#     *   **Score: 2/10**
#     *   **Analysis:** This job is a poor fit. While it mentions "Agile," its core requirements are for highly specialized mobile (Swift/SwiftUI) and Windows desktop (C#.NET, WPF) development, which are outside your listed skills. Your Java, React, and Spring-boot expertise are not relevant here.
#
# *   **Software Engineer | Chennai, India - Hitachi Energy**
#     *   **Score: 1/10**
#     *   **Analysis:** This posting provides almost no technical details beyond the title "Software Engineer." Without further information, it's impossible to assess skill alignment or suitability for your profile. You would need to investigate the full job description via the application link to determine if it's a match.
#
# ---
#
# ### Next Steps
#
# It is highly recommended to prioritize applying for the **Roku - Sr. SW Engineer** and **NatWest Digital X - Software Engineer** roles. For both, tailor your resume and cover letter to highlight the explicitly mentioned skills (Java/Spring-boot for Roku, React/Agile for NatWest) and demonstrate how your experience aligns with their specific project types.
#
# Good luck with your applications!
#
# 📨 Auto-sending report to your email...
#
# 📨 Sending email...
# ✅ Email sent successfully!

# %%
# !pip install crewai
# Out:
# Requirement already satisfied: crewai in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from crewai) (8.3.1)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.13.0)
# Requirement already satisfied: json-repair==0.25.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.25.2)
# Requirement already satisfied: json5>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.12.1)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: mcp>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.22.0)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.8.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.37.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.11.8)
# Requirement already satisfied: portalocker==2.7.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.12.0)
# Requirement already satisfied: pydantic>=2.11.9 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.12.3)
# Requirement already satisfied: pyjwt>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.2.1)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from crewai) (2025.11.3)
# Requirement already satisfied: tokenizers>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.22.1)
# Requirement already satisfied: tomli-w>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.3.0)
# Requirement already satisfied: uv>=0.4.25 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.9.13)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (2.0.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.23.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.37.0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.25.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.13.2)
# Requirement already satisfied: diskcache>=5.6.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: jiter<0.12,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.11.1)
# Requirement already satisfied: pre-commit>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (4.5.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (2.41.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (2.32.5)
# Requirement already satisfied: ty>=0.0.1a23 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.0.1a29)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.48.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.16.0->crewai) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.30.0->crewai) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.37.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.37.0->opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.58b0)
# Requirement already satisfied: pdfminer.six==20251107 in /usr/local/lib/python3.12/dist-packages (from pdfplumber>=0.11.4->crewai) (20251107)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber>=0.11.4->crewai) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber>=0.11.4->crewai) (5.1.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber>=0.11.4->crewai) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber>=0.11.4->crewai) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.20.3->crewai) (0.36.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.5->mcp>=1.16.0->crewai) (3.11)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (25.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb~=1.1.0->crewai) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.20.3->crewai) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.30.0->crewai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.29.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.14.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (20.35.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber>=0.11.4->crewai) (2.0.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (4.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber>=0.11.4->crewai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.6.1)

# %%
# from crewai.scheduler import Scheduler

# USER_PROFILE = """
# I am a Software Engineer
# Skills: Java, Javascript, React, Spring-boot, Agile.
# """

# USER_JOB_REQUEST = "Software Engineer jobs in India for freshers"

# scheduler = Scheduler()

# @scheduler.daily(hour=7, minute=0)
# def run_agent_daily():
#     final_report = recruiter_agent(
#         prompt=USER_JOB_REQUEST,
#         user_profile=USER_PROFILE,
#         client=client,
#         model=AGENT_MODEL
#     )
#     send_email(
#         to_email="your_email@gmail.com",
#         subject="Your Daily Job Report",
#         body=final_report
#     )

# if __name__ == "__main__":
#     scheduler.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1050059592.py in <cell line: 0>()
# ----> 1 from crewai.scheduler import Scheduler
#       2
#       3 USER_PROFILE = """
#       4 I am a Software Engineer
#       5 Skills: Java, Javascript, React, Spring-boot, Agile.
#
# ModuleNotFoundError: No module named 'crewai.scheduler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
